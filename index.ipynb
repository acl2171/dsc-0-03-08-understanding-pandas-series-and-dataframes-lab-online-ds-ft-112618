# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
df.columns= [col.lower() for col in df.columns] #why do we need [] here? Because it's list comprehension. 
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %% [markdown]
# # Change the Index to be the Line Names

# %%
df=df.set_index('linename')
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
df = df.reset_index()
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
df['Num_Lines']=df.linename.map(lambda x: len(x))
df.head(2)
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
#
#    Num_Lines
# 0          7
# 1          7

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.strip()
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'Num_Lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
df.date = pd.to_datetime(df.date)
df['Dayofweek']=df.date.dt.dayofweek
grouped = df.groupby('Dayofweek').sum()
grouped.plot(kind='barh')

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Q: Why doesn't this work? 
grouped
grouped['IsWeekend'] = grouped.Dayofweek.map({0:False,1:False,2:False,3:False,4:False,5:True,6:True})
wkend = grouped.groupby('IsWeekend').mean()
wkend[['ENTRIES', 'EXITS']].plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-a4906b83e35f> in <module>()
#       1 grouped
# ----> 2 grouped['IsWeekend'] = grouped.Dayofweek.map({0:False,1:False,2:False,3:False,4:False,5:True,6:True})
#       3 wkend = grouped.groupby('IsWeekend').mean()
#       4 wkend[['ENTRIES', 'EXITS']].plot(kind='barh')
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Dayofweek'

# %% [markdown]
# # Drop a couple of columns

# %%
df.head()
df.drop('division', axis=1)
# Out:
#        linename    c/a  unit       scp        station       date      time  \
# 0       NQR456W   A002  R051  02-00-00          59 ST 2018-08-25  00:00:00
# 1       NQR456W   A002  R051  02-00-00          59 ST 2018-08-25  04:00:00
# 2       NQR456W   A002  R051  02-00-00          59 ST 2018-08-25  08:00:00
# 3       NQR456W   A002  R051  02-00-00          59 ST 2018-08-25  12:00:00
# 4       NQR456W   A002  R051  02-00-00          59 ST 2018-08-25  16:00:00
# 5       NQR456W   A002  R051  02-00-00          59 ST 2018-08-25  20:00:00
# 6       NQR456W   A002  R051  02-00-00          59 ST 2018-08-26  00:00:00
# 7       NQR456W   A002  R051  02-00-00          59 ST 2018-08-26  04:00:00
# 8       NQR456W   A002  R051  02-00-00          59 ST 2018-08-26  08:00:00
# 9       NQR456W   A002  R051  02-00-00          59 ST 2018-08-26  12:00:00
# 10      NQR456W   A002  R051  02-00-00          59 ST 2018-08-26  16:00:00
# 11      NQR456W   A002  R051  02-00-00          59 ST 2018-08-26  20:00:00
# 12      NQR456W   A002  R051  02-00-00          59 ST 2018-08-27  00:00:00
# 13      NQR456W   A002  R051  02-00-00          59 ST 2018-08-27  04:00:00
# 14      NQR456W   A002  R051  02-00-00          59 ST 2018-08-27  08:00:00
# 15      NQR456W   A002  R051  02-00-00          59 ST 2018-08-27  12:00:00
# 16      NQR456W   A002  R051  02-00-00          59 ST 2018-08-27  16:00:00
# 17      NQR456W   A002  R051  02-00-00          59 ST 2018-08-27  20:00:00
# 18      NQR456W   A002  R051  02-00-00          59 ST 2018-08-28  00:00:00
# 19      NQR456W   A002  R051  02-00-00          59 ST 2018-08-28  04:00:00
# 20      NQR456W   A002  R051  02-00-00          59 ST 2018-08-28  08:00:00
# 21      NQR456W   A002  R051  02-00-00          59 ST 2018-08-28  12:00:00
# 22      NQR456W   A002  R051  02-00-00          59 ST 2018-08-28  16:00:00
# 23      NQR456W   A002  R051  02-00-00          59 ST 2018-08-28  20:00:00
# 24      NQR456W   A002  R051  02-00-00          59 ST 2018-08-29  00:00:00
# 25      NQR456W   A002  R051  02-00-00          59 ST 2018-08-29  04:00:00
# 26      NQR456W   A002  R051  02-00-00          59 ST 2018-08-29  08:00:00
# 27      NQR456W   A002  R051  02-00-00          59 ST 2018-08-29  12:00:00
# 28      NQR456W   A002  R051  02-00-00          59 ST 2018-08-29  16:00:00
# 29      NQR456W   A002  R051  02-00-00          59 ST 2018-08-29  20:00:00
# ...         ...    ...   ...       ...            ...        ...       ...
# 197595        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2018-08-27  01:00:00
# 197596        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2018-08-27  05:00:00
# 197597        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2018-08-27  09:00:00
# 197598        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2018-08-27  13:00:00
# 197599        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2018-08-27  17:00:00
# 197600        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2018-08-27  21:00:00
# 197601        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2018-08-28  01:00:00
# 197602        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2018-08-28  05:00:00
# 197603        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2018-08-28  09:00:00
# 197604        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT 2018-08